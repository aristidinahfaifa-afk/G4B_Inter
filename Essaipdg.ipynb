# %%
from IPython.display import HTML

HTML("""
<style>
@import url('https://fonts.googleapis.com/css2?family=Cormorant+Garamond:ital,wght@0,400;0,600;0,700;1,400&family=DM+Sans:wght@300;400;500&display=swap');
@import url('https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css');

.cover {
    background: linear-gradient(160deg, #0d0d0d 60%, #1a1500 100%);
    border: 1px solid #2a2a2a;
    border-top: 4px solid #c9a84c;
    border-radius: 16px;
    padding: 56px 64px;
    font-family: 'DM Sans', sans-serif;
    color: #e8e4dc;
    position: relative;
    overflow: hidden;
    max-width: 860px;
    margin: 20px auto;
}

/* Watermark décoratif */
.cover::before {
    content: '⚜';
    position: absolute;
    right: 56px;
    bottom: 40px;
    font-size: 9rem;
    color: #c9a84c;
    opacity: 0.05;
    line-height: 1;
}

.cover-header {
    display: flex;
    justify-content: space-between;
    align-items: flex-start;
    margin-bottom: 48px;
}

.cover-header img {
    height: 56px;
    filter: brightness(0) invert(1);
    opacity: 0.85;
}

.cover-badge {
    display: inline-block;
    border: 1px solid #c9a84c;
    color: #c9a84c;
    font-size: 0.68rem;
    padding: 4px 14px;
    border-radius: 20px;
    letter-spacing: 0.14em;
    text-transform: uppercase;
    margin-bottom: 20px;
}

.cover-title {
    font-family: 'Cormorant Garamond', serif;
    font-size: 2.6rem;
    font-weight: 700;
    color: #c9a84c;
    line-height: 1.15;
    margin: 0 0 10px 0;
}

.cover-subtitle {
    font-size: 1rem;
    color: #9a9a9a;
    font-weight: 300;
    margin-bottom: 48px;
    line-height: 1.6;
}

.cover-divider {
    height: 1px;
    background: linear-gradient(90deg, #c9a84c, transparent);
    margin: 32px 0;
    opacity: 0.4;
}

.cover-urne {
    text-align: center;
    margin: 32px 0;
}

.cover-urne svg {
    width: 90px;
    opacity: 0.85;
}

.cover-meta {
    display: grid;
    grid-template-columns: 1fr 1fr;
    gap: 12px 40px;
    margin-bottom: 40px;
}

.cover-meta-item .label {
    font-size: 0.68rem;
    color: #666;
    text-transform: uppercase;
    letter-spacing: 0.1em;
    margin-bottom: 3px;
}

.cover-meta-item .value {
    font-family: 'Cormorant Garamond', serif;
    font-size: 1.05rem;
    color: #e8e4dc;
}

.cover-membres {
    display: flex;
    gap: 12px;
    flex-wrap: wrap;
    margin-top: 8px;
}

.cover-membre {
    background: #161616;
    border: 1px solid #2a2a2a;
    border-radius: 8px;
    padding: 10px 18px;
    font-family: 'Cormorant Garamond', serif;
    font-size: 1rem;
    color: #e8e4dc;
}

.cover-membre span {
    display: block;
    font-family: 'DM Sans', sans-serif;
    font-size: 0.68rem;
    color: #c9a84c;
    letter-spacing: 0.06em;
    text-transform: uppercase;
    margin-top: 3px;
}
</style>

<div class='cover'>

    <!-- Header : logo ENSAI -->
    <div class='cover-header'>
        <img src='https://upload.wikimedia.org/wikipedia/fr/b/b5/Logo_ENSAI_2014.svg'
             alt='ENSAI' onerror="this.style.display='none'">
    </div>

    <!-- Badge -->
    <div class='cover-badge'>Évaluation intermédiaire · 2026</div>

    <!-- Titre -->
    <div class='cover-title'>Exploitation de données<br>électorales avec Python</div>
    <div class='cover-subtitle'>
        Analyse territoriale des résultats du 1er tour<br>
        de l'élection présidentielle française · 10 avril 2022
    </div>

    <!-- Urne SVG -->
    <div class='cover-urne'>
        <svg viewBox='0 0 100 120' xmlns='http://www.w3.org/2000/svg'>
            <!-- Corps urne -->
            <rect x='15' y='40' width='70' height='70' rx='6'
                  fill='none' stroke='#c9a84c' stroke-width='2.5'/>
            <!-- Couvercle -->
            <rect x='10' y='30' width='80' height='14' rx='4'
                  fill='none' stroke='#c9a84c' stroke-width='2.5'/>
            <!-- Fente bulletin -->
            <rect x='40' y='30' width='20' height='4' rx='2'
                  fill='#c9a84c'/>
            <!-- Bulletin qui entre -->
            <rect x='43' y='18' width='14' height='16' rx='2'
                  fill='none' stroke='#c9a84c' stroke-width='2'
                  stroke-dasharray='3,2'/>
            <!-- Lignes bulletin -->
            <line x1='46' y1='22' x2='54' y2='22'
                  stroke='#c9a84c' stroke-width='1.2'/>
            <line x1='46' y1='26' x2='54' y2='26'
                  stroke='#c9a84c' stroke-width='1.2'/>
            <!-- Poignées -->
            <line x1='15' y1='70' x2='5' y2='70'
                  stroke='#c9a84c' stroke-width='2.5' stroke-linecap='round'/>
            <line x1='85' y1='70' x2='95' y2='70'
                  stroke='#c9a84c' stroke-width='2.5' stroke-linecap='round'/>
            <!-- Détail bas -->
            <line x1='15' y1='90' x2='85' y2='90'
                  stroke='#c9a84c' stroke-width='1' opacity='0.3'/>
        </svg>
    </div>

    <div class='cover-divider'></div>

    <!-- Métadonnées -->
    <div class='cover-meta'>
        <div class='cover-meta-item'>
            <div class='label'>Cours</div>
            <div class='value'>Python pour la data science</div>
        </div>
        <div class='cover-meta-item'>
            <div class='label'>Enseignant</div>
            <div class='value'>Lino Galiana · INSEE</div>
        </div>
        <div class='cover-meta-item'>
            <div class='label'>Groupe</div>
            <div class='value'>G4B</div>
        </div>
        <div class='cover-meta-item'>
            <div class='label'>Date de rendu</div>
            <div class='value'>31 mars 2026</div>
        </div>
    </div>

    <div class='cover-divider'></div>

    <!-- Membres -->
    <div style='font-size:0.68rem;color:#666;text-transform:uppercase;
                letter-spacing:0.1em;margin-bottom:12px;'>Membres du groupe</div>
    <div class='cover-membres'>
        <div class='cover-membre'>Membre 1<span>Q1 · Q2 · Q3</span></div>
        <div class='cover-membre'>Membre 2<span>Q4 · Q5 · Q6</span></div>
        <div class='cover-membre'>Membre 3<span>Q7 · Q8</span></div>
    </div>

</div>
""")
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Cormorant+Garamond:ital,wght@0,400;0,600;0,700;1,400&family=DM+Sans:wght@300;400;500&display=swap');
# @import url('https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css');
#
# .cover {
#     background: linear-gradient(160deg, #0d0d0d 60%, #1a1500 100%);
#     border: 1px solid #2a2a2a;
#     border-top: 4px solid #c9a84c;
#     border-radius: 16px;
#     padding: 56px 64px;
#     font-family: 'DM Sans', sans-serif;
#     color: #e8e4dc;
#     position: relative;
#     overflow: hidden;
#     max-width: 860px;
#     margin: 20px auto;
# }
#
# /* Watermark décoratif */
# .cover::before {
#     content: '⚜';
#     position: absolute;
#     right: 56px;
#     bottom: 40px;
#     font-size: 9rem;
#     color: #c9a84c;
#     opacity: 0.05;
#     line-height: 1;
# }
#
# .cover-header {
#     display: flex;
#     justify-content: space-between;
#     align-items: flex-start;
# ...

# %% [markdown]
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Baskerville:ital,wght@0,400;0,700;1,400&family=Source+Sans+3:wght@300;400;600&display=swap');
#
# .cover {
#     background: linear-gradient(175deg, #f8faff 0%, #eef3fb 100%);
#     border: 1px solid #c8d8f0;
#     border-top: 5px solid #1a3a6b;
#     border-radius: 12px;
#     padding: 52px 64px;
#     font-family: 'Source Sans 3', sans-serif;
#     color: #1a1a2e;
#     position: relative;
#     overflow: hidden;
#     max-width: 820px;
#     margin: 20px auto;
#     box-shadow: 0 4px 32px rgba(26,58,107,0.08);
# }
# .cover::before {
#     content: '';
#     position: absolute;
#     top: 0; right: 0;
#     width: 320px; height: 320px;
#     background: radial-gradient(circle at top right, rgba(26,58,107,0.06), transparent 70%);
#     pointer-events: none;
# }
# .cover-header {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     margin-bottom: 44px;
#     padding-bottom: 24px;
#     border-bottom: 1px solid #c8d8f0;
# }
# .cover-logo img {
#     height: 52px;
#     background: #1a1a2e00;
#     border-radius: 6px;
#     padding: 6px 10px;
# }
# .cover-badge {
#     font-size: 0.72rem;
#     font-weight: 600;
#     letter-spacing: 0.12em;
#     text-transform: uppercase;
#     color: #1a3a6b;
#     border: 1.5px solid #1a3a6b;
#     padding: 4px 14px;
#     border-radius: 20px;
#     opacity: 0.7;
# }
# .cover-urne {
#     display: flex;
#     justify-content: center;
#     margin: 0 0 32px 0;
# }
# .cover-title {
#     font-family: 'Libre Baskerville', serif;
#     font-size: 2.4rem;
#     font-weight: 700;
#     color: #1a3a6b;
#     line-height: 1.2;
#     margin: 0 0 12px 0;
# }
# .cover-subtitle {
#     font-size: 1rem;
#     color: #5a6a80;
#     font-weight: 300;
#     line-height: 1.7;
#     margin-bottom: 40px;
# }
# .cover-divider {
#     height: 1px;
#     background: linear-gradient(90deg, #1a3a6b, transparent);
#     margin: 32px 0;
#     opacity: 0.25;
# }
# .cover-grid {
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     gap: 10px 48px;
#     margin-bottom: 36px;
# }
# .cover-meta-item .lbl {
#     font-size: 0.65rem;
#     text-transform: uppercase;
#     letter-spacing: 0.12em;
#     color: #8a9ab0;
#     margin-bottom: 3px;
# }
# .cover-meta-item .val {
#     font-family: 'Libre Baskerville', serif;
#     font-size: 0.98rem;
#     color: #1a3a6b;
# }
# .cover-membres-title {
#     font-size: 0.65rem;
#     text-transform: uppercase;
#     letter-spacing: 0.12em;
#     color: #8a9ab0;
#     margin-bottom: 12px;
# }
# .cover-membres {
#     display: flex;
#     gap: 10px;
#     flex-wrap: wrap;
# }
# .cover-membre {
#     background: white;
#     border: 1px solid #c8d8f0;
#     border-radius: 8px;
#     padding: 10px 18px;
#     flex: 1;
#     min-width: 160px;
# }
# .cover-membre .nom {
#     font-family: 'Libre Baskerville', serif;
#     font-size: 0.95rem;
#     color: #1a3a6b;
#     font-weight: 700;
# }
# .cover-membre .role {
#     font-size: 0.72rem;
#     color: #8a9ab0;
#     margin-top: 3px;
# }
# </style>
#
# <div class="cover">
#
#   <div class="cover-header">
#     <div class="cover-logo">
#       <img src="ressources/logo_ensai.png" alt="ENSAI"/>
#     </div>
#     <div class="cover-badge">Évaluation intermédiaire · 2025-2026</div>
#   </div>
#
#   <div class="cover-title">Exploitation de données électorales avec Python</div>
#
#   <div class="cover-urne">
#     <svg width="72" height="88" viewBox="0 0 100 120" xmlns="http://www.w3.org/2000/svg">
#       <rect x="15" y="40" width="70" height="70" rx="6"
#             fill="none" stroke="#1a3a6b" stroke-width="2.5"/>
#       <rect x="10" y="30" width="80" height="14" rx="4"
#             fill="none" stroke="#1a3a6b" stroke-width="2.5"/>
#       <rect x="40" y="30" width="20" height="4" rx="2" fill="#1a3a6b"/>
#       <rect x="43" y="14" width="14" height="18" rx="2"
#             fill="none" stroke="#1a3a6b" stroke-width="2" stroke-dasharray="3,2"/>
#       <line x1="46" y1="19" x2="54" y2="19" stroke="#1a3a6b" stroke-width="1.2"/>
#       <line x1="46" y1="24" x2="54" y2="24" stroke="#1a3a6b" stroke-width="1.2"/>
#       <line x1="15" y1="70" x2="5" y2="70" stroke="#1a3a6b" stroke-width="2.5" stroke-linecap="round"/>
#       <line x1="85" y1="70" x2="95" y2="70" stroke="#1a3a6b" stroke-width="2.5" stroke-linecap="round"/>
#       <line x1="15" y1="90" x2="85" y2="90" stroke="#1a3a6b" stroke-width="1" opacity="0.3"/>
#     </svg>
#   </div>
#
#
#   <div class="cover-subtitle">
#     Analyse territoriale des résultats du 1<sup>er</sup> tour de l'élection présidentielle française · 10 avril 2022
#   </div>
#
#   <div class="cover-divider"></div>
#
#   <div class="cover-grid">
#     <div class="cover-meta-item">
#       <div class="lbl">Cours</div>
#       <div class="val">Python pour la data science</div>
#     </div>
#     <div class="cover-meta-item">
#       <div class="lbl">Groupe</div>
#       <div class="val">G4B</div>
#     </div>
#
#   </div>
#
#   <div class="cover-divider"></div>
#
#   <div class="cover-membres-title">Membres du groupe</div>
#   <div class="cover-membres">
#     <div class="cover-membre">
#       <div class="nom">AÏFA Aristidina</div>
#     </div>
#     <div class="cover-membre">
#       <div class="nom">KENNE Lesline</div>
#     </div>
#     <div class="cover-membre">
#       <div class="nom">ROSE Valentin</div>
#     </div>
#   </div>
#
# </div>

# %% [markdown]
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Libre+Baskerville:ital,wght@0,400;0,700;1,400&family=Source+Sans+3:wght@300;400;600&display=swap");
#
# .cover {
#     background: #ffffff;
#     border-top: 6px solid #1a3a6b;
#     border-bottom: 2px solid #e0e8f0;
#     padding: 52px 64px;
#     font-family: "Source Sans 3", sans-serif;
#     color: #1a1a2e;
#     max-width: 820px;
#     margin: 20px auto;
# }
# .cover-header {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     margin-bottom: 40px;
#     padding-bottom: 24px;
#     border-bottom: 1px solid #e0e8f0;
# }
# .cover-logo img {
#     height: 56px;
#     background: #ffffff;
#     border-radius: 4px;
#     padding: 4px;
# }
# .cover-badge {
#     font-size: 0.7rem;
#     font-weight: 600;
#     letter-spacing: 0.14em;
#     text-transform: uppercase;
#     color: #1a3a6b;
#     border: 1.5px solid #1a3a6b;
#     padding: 5px 16px;
#     border-radius: 20px;
# }
# .cover-body {
#     display: flex;
#     align-items: flex-start;
#     gap: 48px;
#     margin-bottom: 40px;
# }
# .cover-urne { flex-shrink: 0; padding-top: 6px; }
# .cover-title {
#     font-family: "Libre Baskerville", serif;
#     font-size: 2.2rem;
#     font-weight: 700;
#     color: #1a3a6b;
#     line-height: 1.25;
#     margin: 0 0 14px 0;
# }
# .cover-subtitle {
#     font-size: 0.97rem;
#     color: #5a6a80;
#     font-weight: 300;
#     line-height: 1.75;
# }
# .cover-divider {
#     height: 1px;
#     background: #e0e8f0;
#     margin: 32px 0;
# }
# .cover-grid {
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     gap: 18px 48px;
#     margin-bottom: 36px;
# }
# .cover-meta-item .lbl {
#     font-size: 0.63rem;
#     text-transform: uppercase;
#     letter-spacing: 0.14em;
#     color: #8a9ab0;
#     margin-bottom: 3px;
# }
# .cover-meta-item .val {
#     font-family: "Libre Baskerville", serif;
#     font-size: 0.95rem;
#     color: #1a3a6b;
# }
# .cover-membres-title {
#     font-size: 0.63rem;
#     text-transform: uppercase;
#     letter-spacing: 0.14em;
#     color: #8a9ab0;
#     margin-bottom: 12px;
# }
# .cover-membres {
#     display: flex;
#     gap: 12px;
# }
# .cover-membre {
#     background: #f4f7fb;
#     border: 1px solid #e0e8f0;
#     border-left: 3px solid #1a3a6b;
#     border-radius: 6px;
#     padding: 12px 18px;
#     flex: 1;
# }
# .cover-membre .nom {
#     font-family: "Libre Baskerville", serif;
#     font-size: 0.93rem;
#     color: #1a3a6b;
#     font-weight: 700;
# }
# .cover-membre .role {
#     font-size: 0.72rem;
#     color: #8a9ab0;
#     margin-top: 3px;
# }
# </style>
#
# <div class="cover">
#
#   <div class="cover-header">
#     <div class="cover-logo">
#       <img src="data:image/png;base64,..." alt="ENSAI"/>
#     </div>
#     <div class="cover-badge">Évaluation intermédiaire &middot; 2026</div>
#   </div>
#
#   <div class="cover-body">
#     <div class="cover-urne">
#       <svg width="64" height="78" viewBox="0 0 100 120" xmlns="http://www.w3.org/2000/svg">
#         <rect x="15" y="40" width="70" height="70" rx="5" fill="#f4f7fb" stroke="#1a3a6b" stroke-width="2.5"/>
#         <rect x="10" y="30" width="80" height="14" rx="4" fill="#f4f7fb" stroke="#1a3a6b" stroke-width="2.5"/>
#         <rect x="40" y="30" width="20" height="4" rx="2" fill="#1a3a6b"/>
#         <rect x="43" y="14" width="14" height="18" rx="2" fill="none" stroke="#1a3a6b" stroke-width="2" stroke-dasharray="3,2"/>
#         <line x1="46" y1="19" x2="54" y2="19" stroke="#1a3a6b" stroke-width="1.2"/>
#         <line x1="46" y1="24" x2="54" y2="24" stroke="#1a3a6b" stroke-width="1.2"/>
#         <line x1="15" y1="70" x2="5" y2="70" stroke="#1a3a6b" stroke-width="2.5" stroke-linecap="round"/>
#         <line x1="85" y1="70" x2="95" y2="70" stroke="#1a3a6b" stroke-width="2.5" stroke-linecap="round"/>
#         <line x1="15" y1="90" x2="85" y2="90" stroke="#e0e8f0" stroke-width="1.5"/>
#       </svg>
#     </div>
#     <div>
#       <div class="cover-title">Exploitation de données<br>électorales avec Python</div>
#       <div class="cover-subtitle">
#         Analyse territoriale des résultats du 1<sup>er</sup> tour<br>
#         de l'élection présidentielle française &mdash; 10 avril 2022
#       </div>
#     </div>
#   </div>
#
#   <div class="cover-divider"></div>
#
#   <div class="cover-grid">
#     <div class="cover-meta-item">
#       <div class="lbl">Cours</div>
#       <div class="val">Python pour la data science</div>
#     </div>
#     <div class="cover-meta-item">
#       <div class="lbl">Enseignant</div>
#       <div class="val">Lino Galiana &mdash; INSEE</div>
#     </div>
#     <div class="cover-meta-item">
#       <div class="lbl">Groupe</div>
#       <div class="val">G4B</div>
#     </div>
#     <div class="cover-meta-item">
#       <div class="lbl">Date de rendu</div>
#       <div class="val">31 mars 2026</div>
#     </div>
#   </div>
#
#   <div class="cover-divider"></div>
#
#   <div class="cover-membres-title">Membres du groupe</div>
#   <div class="cover-membres">
#     <div class="cover-membre"><div class="nom">Membre 1</div><div class="role">Q1 &middot; Q2 &middot; Q3</div></div>
#     <div class="cover-membre"><div class="nom">Membre 2</div><div class="role">Q4 &middot; Q5 &middot; Q6</div></div>
#     <div class="cover-membre"><div class="nom">Membre 3</div><div class="role">Q7 &middot; Q8</div></div>
#   </div>
#
# </div>
