# %% [markdown]
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Baskerville:ital,wght@0,400;0,700;1,400&family=Source+Sans+3:wght@300;400;600&display=swap');
#
# .cover {
#     background: linear-gradient(175deg, #f8faff 0%, #eef3fb 100%);
#     border: 1px solid #c8d8f0;
#     border-top: 5px solid #1a3a6b;
#     border-radius: 12px;
#     padding: 52px 64px;
#     font-family: 'Source Sans 3', sans-serif;
#     color: #1a1a2e;
#     position: relative;
#     overflow: hidden;
#     max-width: 820px;
#     margin: 20px auto;
#     box-shadow: 0 4px 32px rgba(26,58,107,0.08);
# }
# .cover::before {
#     content: '';
#     position: absolute;
#     top: 0; right: 0;
#     width: 320px; height: 320px;
#     background: radial-gradient(circle at top right, rgba(26,58,107,0.06), transparent 70%);
#     pointer-events: none;
# }
# .cover-header {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     margin-bottom: 44px;
#     padding-bottom: 24px;
#     border-bottom: 1px solid #c8d8f0;
# }
# .cover-logo img {
#     height: 52px;
#     background: #1a1a2e00;
#     border-radius: 6px;
#     padding: 6px 10px;
# }
# .cover-badge {
#     font-size: 0.72rem;
#     font-weight: 600;
#     letter-spacing: 0.12em;
#     text-transform: uppercase;
#     color: #1a3a6b;
#     border: 1.5px solid #1a3a6b;
#     padding: 4px 14px;
#     border-radius: 20px;
#     opacity: 0.7;
# }
# .cover-urne {
#     display: flex;
#     justify-content: center;
#     margin: 0 0 32px 0;
# }
# .cover-title {
#     font-family: 'Libre Baskerville', serif;
#     font-size: 2.4rem;
#     font-weight: 700;
#     color: #1a3a6b;
#     line-height: 1.2;
#     margin: 0 0 12px 0;
# }
# .cover-subtitle {
#     font-family: 'Libre Baskerville', serif;
#     font-size: 1rem;
#     color: #000408;
#     font-weight: 500;
#     line-height: 1.7;
#     margin-bottom: 40px;
# }
# .cover-divider {
#     height: 1px;
#     background: linear-gradient(90deg, #1a3a6b, transparent);
#     margin: 32px 0;
#     opacity: 0.25;
# }
# .cover-grid {
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     gap: 10px 48px;
#     margin-bottom: 36px;
# }
# .cover-meta-item .lbl {
#     font-size: 0.65rem;
#     text-transform: uppercase;
#     letter-spacing: 0.12em;
#     color: #8a9ab0;
#     margin-bottom: 3px;
# }
# .cover-meta-item .val {
#     font-family: 'Libre Baskerville', serif;
#     font-size: 0.98rem;
#     color: #1a3a6b;
# }
# .cover-membres-title {
#     font-size: 0.65rem;
#     text-transform: uppercase;
#     letter-spacing: 0.12em;
#     color: #8a9ab0;
#     margin-bottom: 12px;
# }
# .cover-membres {
#     display: flex;
#     gap: 10px;
#     flex-wrap: wrap;
# }
# .cover-membre {
#     background: white;
#     border: 1px solid #c8d8f0;
#     border-radius: 8px;
#     padding: 10px 18px;
#     flex: 1;
#     min-width: 160px;
# }
# .cover-membre .nom {
#     font-family: 'Libre Baskerville', serif;
#     font-size: 0.95rem;
#     color: #1a3a6b;
#     font-weight: 700;
# }
# .cover-membre .role {
#     font-size: 0.72rem;
#     color: #8a9ab0;
#     margin-top: 3px;
# }
# </style>
#
# <div class="cover">
#
#   <div class="cover-header">
#     <div class="cover-logo">
#       <img src="ressources/logo_ensai.png" alt="ENSAI"/>
#     </div>
#     <div class="cover-badge">Évaluation intermédiaire · 2025-2026</div>
#   </div>
#
#   <div class="cover-title">Exploitation de données électorales avec Python</div>
#
#   <div class="cover-urne">
#     <svg width="72" height="88" viewBox="0 0 100 120" xmlns="http://www.w3.org/2000/svg">
#       <rect x="15" y="40" width="70" height="70" rx="6"
#             fill="none" stroke="#1a3a6b" stroke-width="2.5"/>
#       <rect x="10" y="30" width="80" height="14" rx="4"
#             fill="none" stroke="#1a3a6b" stroke-width="2.5"/>
#       <rect x="40" y="30" width="20" height="4" rx="2" fill="#1a3a6b"/>
#       <rect x="43" y="14" width="14" height="18" rx="2"
#             fill="none" stroke="#1a3a6b" stroke-width="2" stroke-dasharray="3,2"/>
#       <line x1="46" y1="19" x2="54" y2="19" stroke="#1a3a6b" stroke-width="1.2"/>
#       <line x1="46" y1="24" x2="54" y2="24" stroke="#1a3a6b" stroke-width="1.2"/>
#       <line x1="15" y1="70" x2="5" y2="70" stroke="#1a3a6b" stroke-width="2.5" stroke-linecap="round"/>
#       <line x1="85" y1="70" x2="95" y2="70" stroke="#1a3a6b" stroke-width="2.5" stroke-linecap="round"/>
#       <line x1="15" y1="90" x2="85" y2="90" stroke="#1a3a6b" stroke-width="1" opacity="0.3"/>
#     </svg>
#   </div>
#
#
#   <div class="cover-subtitle">
#     <b> Analyse territoriale des résultats du 1<sup>er</sup> tour de l'élection présidentielle française · 10 avril 2022</b>
#   </div>
#
#   <div class="cover-divider"></div>
#
#   <div class="cover-grid">
#     <div class="cover-meta-item">
#       <div class="lbl">Cours</div>
#       <div class="val">Python pour la data science</div>
#     </div>
#     <div class="cover-meta-item">
#       <div class="lbl">Groupe</div>
#       <div class="val">G4B</div>
#     </div>
#
#   </div>
#
#   <div class="cover-divider"></div>
#
#   <div class="cover-membres-title">Membres du groupe</div>
#   <div class="cover-membres">
#     <div class="cover-membre">
#       <div class="nom">AÏFA Aristidina</div>
#     </div>
#     <div class="cover-membre">
#       <div class="nom">KENNE Lesline</div>
#     </div>
#     <div class="cover-membre">
#       <div class="nom">ROSE Valentin</div>
#     </div>
#   </div>
#
#
# </div>

# %% [markdown]
# # Importation des bibliothèques

# %%
import pandas as pd
from utils import  beau_tableau, carte_par_candidat, cartes_plusieurs_candidats, diagnostic_qualite
import matplotlib.pyplot as plt
import seaborn as sns  
from cartiflette import carti_download

# %% [markdown]
# # Importation du dataset

# %%
# Importation
df = pd.read_csv(
 'https://www.data.gouv.fr/fr/datasets/r/182268fc-2103-4bcb-a850-6cf90b02a9eb' 
)
# Out:
# /tmp/ipykernel_1881150/1196414799.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %% [markdown]
# # 0. Explorations de la base de données

# %%
print("Aperçu du dataset  : ")
df.head(3)
# Out:
# Aperçu du dataset  :
#   code_departement libelle_departement  code_commune          libelle_commune  \
# 0               01                 Ain             1  L'Abergement-Clémenciat
# 1               01                 Ain             2    L'Abergement-de-Varey
# 2               01                 Ain             4        Ambérieu-en-Bugey
#
#      prenom      nom  voix
# 0  Nathalie  ARTHAUD     3
# 1  Nathalie  ARTHAUD     2
# 2  Nathalie  ARTHAUD    38

# %%
# Aperçu général
print(f"Dimension du dataset : {df.shape}")
print(f"Type des variables  : {df.dtypes}")
# Out:
# Dimension du dataset : (528675, 7)
# Type des variables  : code_departement       object
# libelle_departement    object
# code_commune            int64
# libelle_commune        object
# prenom                 object
# nom                    object
# voix                    int64
# dtype: object

# %% [markdown]
# On va spécifier les types des variables pour un travail plus fluide.

# %%
df = df.convert_dtypes()
print(df.dtypes)
# Out:
# code_departement       string[python]
# libelle_departement    string[python]
# code_commune                    Int64
# libelle_commune        string[python]
# prenom                 string[python]
# nom                    string[python]
# voix                            Int64
# dtype: object

# %% [markdown]
# On a utilisé la méthode `convert_dtypes` pour avoir les bons types de manière automatique pour les variables. On remarque que le type du `code commune` ne semble pas approprié.

# %%
df["code_commune"] = df["code_commune"].astype("string")

# %% [markdown]
# ## Diagnostic général de la base
# Avant tout traitement, on vérifie la qualité des données : valeurs manquantes, doublons et cohérence de la colonne .

# %%
diagnostic_qualite(df)
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# GT(_tbl_data=  Variable  Nombre de valeurs manquantes  Part (%)
# 4   prenom                        105735      20.0, _body=<great_tables._gt_data.Body object at 0x7f32987bde80>, _boxhead=Boxhead([ColInfo(var='Variable', type=<ColInfoTypeEnum.default: 1>, column_label='Variable', column_align='left', column_width=None), ColInfo(var='Nombre de valeurs manquantes', type=<ColInfoTypeEnum.default: 1>, column_label='Nombre de valeurs manquantes', column_align='right', column_width=None), ColInfo(var='Part (%)', type=<ColInfoTypeEnum.default: 1>, column_label='Part (%)', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f32987be510>, _spanners=Spanners([]), _heading=Heading(title=Md(text='**Variables avec les valeurs manquantes**'), subtitle=Md(text='Qualité des données '), preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f32987be3c0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f32987b5310>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Variable', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Nombre de valeurs manquantes', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Part (%)', rownum=0, colnum=None, styles=[CellStyleFill(color='white')])], _locale=<great_tables._gt_data.Locale object at 0x7f32987be660>, _formats=[<great_tables._gt_data.FormatInfo object at 0x7f32987be270>, <great_tables._gt_data.FormatInfo object at 0x7f32987b5950>], _substitutions=[], _col_merge=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['Times New Roman']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value ...
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# GT(_tbl_data=   Type de doublon  Nombre
# 0  Doublons exacts       0, _body=<great_tables._gt_data.Body object at 0x7f32989662c0>, _boxhead=Boxhead([ColInfo(var='Type de doublon', type=<ColInfoTypeEnum.default: 1>, column_label='Type de doublon', column_align='left', column_width=None), ColInfo(var='Nombre', type=<ColInfoTypeEnum.default: 1>, column_label='Nombre', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f32987b5590>, _spanners=Spanners([]), _heading=Heading(title=Md(text='**Doublons**'), subtitle=Md(text='Vérification '), preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f32987b4e10>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f32989663f0>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocColumnLabels(columns='Type de doublon'), grpname=None, colname='Type de doublon', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='Nombre'), grpname=None, colname='Nombre', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Type de doublon', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Nombre', rownum=0, colnum=None, styles=[CellStyleFill(color='white')])], _locale=<great_tables._gt_data.Locale object at 0x7f32987b4f50>, _formats=[<great_tables._gt_data.FormatInfo object at 0x7f32987b5810>], _substitutions=[], _col_merge=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['Times New Roman']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss ...
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# GT(_tbl_data=  Indicateur       Valeur
# 0      count     528675.0
# 1       mean    92.207644
# 2        std  1075.348381
# 3        min          0.0
# 4        25%          3.0
# 5        50%         11.0
# 6        75%         42.0
# 7        max     372820.0, _body=<great_tables._gt_data.Body object at 0x7f32987a1590>, _boxhead=Boxhead([ColInfo(var='Indicateur', type=<ColInfoTypeEnum.default: 1>, column_label='Indicateur', column_align='left', column_width=None), ColInfo(var='Valeur', type=<ColInfoTypeEnum.default: 1>, column_label='Valeur', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f32987b5810>, _spanners=Spanners([]), _heading=Heading(title=Md(text='**Distribution des votes**'), subtitle=Md(text='Statistiques descriptives '), preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f3298965e00>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f329879f650>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Indicateur', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Indicateur', rownum=1, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Indicateur', rownum=2, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Indicateur', rownum=3, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Indicateur', rownum=4, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Indicateur', rownum=5, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Indicateur', rownum=6, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Indicateur', rownum=7, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Valeur', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Valeur', rownum=1, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Valeur', rownum=2, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Valeur', rownum=3, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Valeur', rownum=4, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Valeur', rownum=5, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Valeur', rownum=6, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Valeur', rownum=7, colnum=None, styles=[CellStyleFill(color='white')])], _locale=<great_tables._gt_data.Locale object at 0x7f32987b5310>, _formats=[<great_tables._gt_data.FormatInfo object at 0x7f3298966780>], _substitutions=[], _col_merge=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='tab ...
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# GT(_tbl_data=                  Indicateur  Nombre
# 0  Candidats sans aucun vote       0, _body=<great_tables._gt_data.Body object at 0x7f3298976450>, _boxhead=Boxhead([ColInfo(var='Indicateur', type=<ColInfoTypeEnum.default: 1>, column_label='Indicateur', column_align='left', column_width=None), ColInfo(var='Nombre', type=<ColInfoTypeEnum.default: 1>, column_label='Nombre', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f3298966780>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f32987a1e10>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f32987a09e0>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocColumnLabels(columns='Indicateur'), grpname=None, colname='Indicateur', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='Nombre'), grpname=None, colname='Nombre', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Indicateur', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Nombre', rownum=0, colnum=None, styles=[CellStyleFill(color='white')])], _locale=<great_tables._gt_data.Locale object at 0x7f3298965e00>, _formats=[<great_tables._gt_data.FormatInfo object at 0x7f3298966650>], _substitutions=[], _col_merge=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['Times New Roman']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), tabl ...

# %% [markdown]
# L’analyse met en évidence une qualité globalement satisfaisante des données. En effet, aucun doublon n’est détecté et tous les candidats disposent d’au moins une voix à l’échelle nationale. Toutefois, la présence de 20 % de valeurs manquantes sur la variable `prénom` mérite d'être pris en compte. Enfin, la distribution des votes apparaît fortement asymétrique, traduisant une forte hétérogénéité territoriale, avec la présence de valeurs extrêmes liées aux grandes communes.

# %% [markdown]
# ## Exploration pour la partie 1

# %%
# Aperçu de la base de données
beau_tableau(df.head(),
col_gras="all"
)
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# GT(_tbl_data=  code_departement libelle_departement code_commune          libelle_commune  \
# 0               01                 Ain            1  L'Abergement-Clémenciat
# 1               01                 Ain            2    L'Abergement-de-Varey
# 2               01                 Ain            4        Ambérieu-en-Bugey
# 3               01                 Ain            5      Ambérieux-en-Dombes
# 4               01                 Ain            6                  Ambléon
#
#      prenom      nom  voix
# 0  Nathalie  ARTHAUD     3
# 1  Nathalie  ARTHAUD     2
# 2  Nathalie  ARTHAUD    38
# 3  Nathalie  ARTHAUD     8
# 4  Nathalie  ARTHAUD     0  , _body=<great_tables._gt_data.Body object at 0x7f3295071c50>, _boxhead=Boxhead([ColInfo(var='code_departement', type=<ColInfoTypeEnum.default: 1>, column_label='code_departement', column_align='left', column_width=None), ColInfo(var='libelle_departement', type=<ColInfoTypeEnum.default: 1>, column_label='libelle_departement', column_align='left', column_width=None), ColInfo(var='code_commune', type=<ColInfoTypeEnum.default: 1>, column_label='code_commune', column_align='left', column_width=None), ColInfo(var='libelle_commune', type=<ColInfoTypeEnum.default: 1>, column_label='libelle_commune', column_align='left', column_width=None), ColInfo(var='prenom', type=<ColInfoTypeEnum.default: 1>, column_label='prenom', column_align='left', column_width=None), ColInfo(var='nom', type=<ColInfoTypeEnum.default: 1>, column_label='nom', column_align='left', column_width=None), ColInfo(var='voix', type=<ColInfoTypeEnum.default: 1>, column_label='voix', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f32989668b0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f329a59a850>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f3298975d50>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocColumnLabels(columns='code_departement'), grpname=None, colname='code_departement', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='libelle_departement'), grpname=None, colname='libelle_departement', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='code_commune'), grpname=None, colname='code_commune', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='libelle_commune'), grpname=None, colname='libelle_commune', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='prenom'), grpname=None, colname='prenom', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='nom'), grpname=None, colname='nom', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='voix'), grpname=None, colname='voix', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=1, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=2, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=Non ...

# %% [markdown]
# **Avant d'attaquer la question 1, on décide d'en savoir plus sur les communes et les départements pour mieux construire le code_commune.**

# %% [markdown]
# Cette partie explore le nombre de caractères dans les codes commune et département

# %%
print(df['code_commune'].str.len().value_counts())
print(df['code_departement'].str.len().value_counts())
# Out:
# code_commune
# 3    403695
# 2    113535
# 1     11445
# Name: count, dtype: Int64
# code_departement
# 2     522300
# 3       3225
# 11      3150
# Name: count, dtype: Int64

# %%
# Voir  les codes départements uniques
df['code_departement'].unique()
# Out:
# <StringArray>
# [         '01',          '02',          '03',          '04',          '05',
#           '06',          '07',          '08',          '09',          '10',
#  ...
#          '973',         '974',         '976',         '988',         '987',
#          '975',         '986',         '977',         '978', 'fr_etranger']
# Length: 108, dtype: string

# %%
# Les départements dont les codes ont une taille de caractères égale à 11
print(df[df['code_departement'].str.len() == 11]['code_departement'].unique())
# Out:
# <StringArray>
# ['fr_etranger']
# Length: 1, dtype: string

# %% [markdown]
# On remarque que les codes des communes sont constitués de chiffres avec 3 chiffes au maximum. Pour les départements on a au maximum une chaine de 11 caractères correspondant à `fr_etranger`.

# %% [markdown]
# Ensuite, on explore le cas particulier des départements à 3 chiffres.

# %%
# Départements avec 3 chiffres
print(df[df['code_departement'].str.len() == 3])
#df[df['code_departement'] == "988"]

# Type de commune avec départements de 3 chiffres 
print(df[df['code_departement'].str.len() == 3]['code_commune'].str.len().value_counts())
# Out:
#        code_departement       libelle_departement code_commune  \
# 34820               971                Guadeloupe          101
# 34821               971                Guadeloupe          102
# 34822               971                Guadeloupe          103
# 34823               971                Guadeloupe          104
# 34824               971                Guadeloupe          105
# ...                 ...                       ...          ...
# 528460              975  Saint-Pierre-et-Miquelon          501
# 528461              975  Saint-Pierre-et-Miquelon          502
# 528462              986          Wallis et Futuna            1
# 528463              977          Saint-Barthélémy          701
# 528464              978              Saint-Martin          801
#
#           libelle_commune    prenom      nom  voix
# 34820          Les Abymes  Nathalie  ARTHAUD   151
# 34821       Anse-Bertrand  Nathalie  ARTHAUD    10
# 34822        Baie-Mahault  Nathalie  ARTHAUD    76
# 34823             Baillif  Nathalie  ARTHAUD    17
# 34824         Basse-Terre  Nathalie  ARTHAUD    34
# ...                   ...       ...      ...   ...
# 528460  Miquelon-Langlade      <NA>     nuls     1
# 528461       Saint-Pierre      <NA>     nuls    24
# 528462   Wallis-Et-Futuna      <NA>     nuls    17
# 528463   Saint-Barthélémy      <NA>     nuls    12
# 528464       Saint-Martin      <NA>     nuls    72
#
# [3225 rows x 7 columns]
# code_commune
# 3    3210
# 1      15
# Name: count, dtype: Int64

# %%
# # Départements de 3 chiffres dont les codes de commune n'ont pas trois chiffres
mask = (df['code_departement'].str.len() == 3) & (df['code_commune'].str.len() != 3)
df[mask][['code_departement', 'code_commune', 'libelle_commune']].drop_duplicates().head(20)
# Out:
#       code_departement code_commune   libelle_commune
# 35032              986            1  Wallis-Et-Futuna

# %%
# Départements de 3 chiffres dont les codes de commune ne commencent pas par le dernier chiffre du code département
# Le but est de savoir si on peut extraire les 2 premiers chiffres du code département dans tous les cas
mask = (df['code_departement'].str.len() == 3) & (df['code_commune'].str.len() == 3)
df_dom = df[mask].copy()

df_dom['dept_last'] = df_dom['code_departement'].str[-1:]
df_dom['commune_first'] = df_dom['code_commune'].str[0]

df_dom[df_dom['dept_last'] != df_dom['commune_first']][['code_departement', 'code_commune', 'dept_last', 'commune_first']].drop_duplicates().head(20)
# Out:
# Empty DataFrame
# Columns: [code_departement, code_commune, dept_last, commune_first]
# Index: []

# %% [markdown]
# Après une vérification initiale des formats, on observe que `code_commune` comporte jusqu'à 3 chiffres et que `code_departement` s'étend de 2 à `fr_etranger` (11), ce qui rend une normalisation nécessaire. Il faut ensuite extraire les cas particuliers, notamment les départements à 3 chiffres (Dom-Tom, etc.) et les communes qui ne suivent pas systématiquement la logique « 2 premiers chiffres du département + code commune ». La recherche de contre-exemples (pour les cas à 3 chiffres de département et 3 chiffres de commune où le premier chiffre diffère du dernier chiffre du département) n'en révèle aucun, ce qui souligne toutefois la complexité d'établir une règle unique. En conclusion, il convient de traiter explicitement les cas particuliers (ex. `fr_etranger` -> `99`, Wallis-et-Futuna, etc.), puis d'harmoniser `code_commune` via `zfill` et une découpe contrôlée afin de garantir des codes cohérents.

# %% [markdown]
# # 1. Explorations générales

# %% [markdown]
# ## Question 1 :  Création et mise à jour des variables
#
# Création ou mise à jours des  variables :
# - `code_commune` : département + commune
# - `candidat` : prénom + nom

# %% [markdown]
# ### Code commune

# %%
#  Remplacer fr_etranger par 99
df['code_departement'] = df['code_departement'].replace('fr_etranger', '99')

# Construire le code commune
df['code_commune'] = (
    df['code_departement'].str[:2]
    + df['code_commune'].str[-3:].str.zfill(3) # pour completer des zeros avant le chiffre pour en avoir 3
)

# Correction Wallis-et-Futuna (986) : on prend les 3 chiffres du département
mask_wallis = df['code_departement'].astype(str) == '986'
df.loc[mask_wallis, 'code_commune'] = (
    '986' + df.loc[mask_wallis, 'code_commune'].str[-1:].str.zfill(2)
)

# Vérification
df['code_commune'].str.len().value_counts()
# Out:
# code_commune
# 5    528675
# Name: count, dtype: Int64

# %% [markdown]
# ### Création de candidat

# %%
df['candidat'] = df['prenom'] + ' ' + df['nom']
df.sample(7)
# Out:
#        code_departement libelle_departement code_commune     libelle_commune  \
# 392611               14            Calvados        14737        Versainville
# 13262                35     Ille-et-Vilaine        35093              Dinard
# 231881               55               Meuse        55473  Saulx-lès-Champlon
# 135440               76      Seine-Maritime        76482         Offranville
# 103925               88              Vosges        88153            Domptail
# 178561               07             Ardèche        07318            Tauriers
# 217371               17   Charente-Maritime        17369  Saint-Martin-de-Ré
#
#           prenom            nom  voix               candidat
# 392611   Nicolas  DUPONT-AIGNAN    10  Nicolas DUPONT-AIGNAN
# 13262   Nathalie        ARTHAUD    29       Nathalie ARTHAUD
# 231881  Jean-Luc      MÉLENCHON    15     Jean-Luc MÉLENCHON
# 135440      Jean       LASSALLE    56          Jean LASSALLE
# 103925  Emmanuel         MACRON    50        Emmanuel MACRON
# 178561      Éric        ZEMMOUR    10           Éric ZEMMOUR
# 217371  Jean-Luc      MÉLENCHON   150     Jean-Luc MÉLENCHON

# %% [markdown]
# ## Question 2 : Complétons la phrase grâce à Python

# %%
# Préliminaires
print(df[df['prenom'].isna()]['nom'].unique()) # toutes les catégories de NA

candidats = df[df['prenom'].notna()]['candidat'].nunique()#on y enlève les na
# Out:
# <StringArray>
# ['abstentions', 'blancs', 'nuls']
# Length: 3, dtype: string

# %% [markdown]
# Les prénoms `NA` n'ont que comme nom : 'abstentions', 'blancs'ou 'nuls'. On les retire de `candidats`.

# %% [markdown]
# *On peut alors écrire la phrase*

# %%
# Phrase
f"En 2022, il y avait {candidats} candidats à l'élection présidentielle."
# Out:
# "En 2022, il y avait 12 candidats à l'élection présidentielle."

# %% [markdown]
# ## Question 3

# %%
# Votes exprimés uniquement (on exclut les lignes sans prénom (nuls, abstentions et blancs))
df_exprimes = df[df['prenom'].notna()]

# Total des voix par candidat
votes_national = df_exprimes.groupby('candidat')['voix'].sum().reset_index()
votes_national.columns = ['Candidat', 'Nombre votes (total)']

# Total général pour calculer les pourcentages
total_exprimes = votes_national['Nombre votes (total)'].sum()

# Score en %
votes_national['Score (% votes exprimés)'] = (votes_national['Nombre votes (total)'] / total_exprimes * 100).round(2)

# Tri décroissant
votes_national = votes_national.sort_values('Nombre votes (total)', ascending=False).reset_index(drop=True)

votes_national.head()
# Out:
#              Candidat  Nombre votes (total)  Score (% votes exprimés)
# 0     Emmanuel MACRON               9783058                     27.85
# 1       Marine LE PEN               8133828                     23.15
# 2  Jean-Luc MÉLENCHON               7712520                     21.95
# 3        Éric ZEMMOUR               2485226                      7.07
# 4    Valérie PÉCRESSE               1679001                      4.78

# %% [markdown]
# *On obtient quelque chose de potable. On passe à la mise en forme.*

# %% [markdown]
# ### Tableau mis en forme

# %%
beau_tableau(
    votes_national,
    col_entiers=["Nombre votes (total)"],
    col_pourcentages=["Score (% votes exprimés)"],
    titre="Elections",
    sous_titre="Résultats du premier tour",
    date="10 avril 2022",
    note="Table 1. Résultats du premier tour de l'élection présidentielle 2022"
)
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# GT(_tbl_data=                 Candidat  Nombre votes (total)  Score (% votes exprimés)
# 0         Emmanuel MACRON               9783058                     27.85
# 1           Marine LE PEN               8133828                     23.15
# 2      Jean-Luc MÉLENCHON               7712520                     21.95
# 3            Éric ZEMMOUR               2485226                      7.07
# 4        Valérie PÉCRESSE               1679001                      4.78
# 5           Yannick JADOT               1627853                      4.63
# 6           Jean LASSALLE               1101387                      3.13
# 7          Fabien ROUSSEL                802422                      2.28
# 8   Nicolas DUPONT-AIGNAN                725176                      2.06
# 9            Anne HIDALGO                616478                      1.75
# 10        Philippe POUTOU                268904                      0.77
# 11       Nathalie ARTHAUD                197094                      0.56, _body=<great_tables._gt_data.Body object at 0x7f32987919d0>, _boxhead=Boxhead([ColInfo(var='Candidat', type=<ColInfoTypeEnum.default: 1>, column_label='Candidat', column_align='left', column_width=None), ColInfo(var='Nombre votes (total)', type=<ColInfoTypeEnum.default: 1>, column_label='Nombre votes (total)', column_align='right', column_width=None), ColInfo(var='Score (% votes exprimés)', type=<ColInfoTypeEnum.default: 1>, column_label='Score (% votes exprimés)', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f32967a8710>, _spanners=Spanners([]), _heading=Heading(title=Md(text='**Elections**'), subtitle=Md(text='Résultats du premier tour (<i class="fa fa-calendar-o" aria-hidden="true"></i> <em>10 avril 2022</em>)'), preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f3297a84140>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f3297a84320>, _source_notes=[Md(text="**Table 1. Résultats du premier tour de l'élection présidentielle 2022**")], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=1, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=2, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=3, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=4, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=5, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=6, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=7, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=8, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=9, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=10, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=11, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Nombre votes (total)', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Nombre votes (total)', rownum=1, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Nombre votes (total)', rownum=2, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Nombre votes (total)', rownum=3, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Nombre votes (total)', rownum=4, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask ...

# %% [markdown]
# Le tableau montre les candidats classés par nombre de voix décroissant, avec le total des voix et le pourcentage des votes exprimés. Emmanuel Macron arrive en tête avec environ 9.78 millions de voix (27.85%), suivi de Marine Le Pen avec environ 8.13 millions (23.15%). Les autres candidats ont des scores inférieurs, avec Jean-Luc Mélenchon à environ 7.71 millions (21.95%).
# Ce tableau représente les résultats nationaux agrégés, excluant les votes blancs ou nuls.

# %% [markdown]
# # Partie 2

# %% [markdown]
# La répartition départemental des votes est-elle la même que la répartition nationale ?

# %%
# data frame des scores par départememt du nombre de votes et du score de chaque candidat
## Tout d'abord, on compte pour chaque candidat le nombre de votes par département
### construction du nombre total de voix pour chaque candidat
votes_departementaux = df_exprimes.groupby(['code_departement', 'candidat'])['voix'].sum().reset_index()
votes_departementaux.columns = ['code_departement', 'Candidat', 'Nombre votes (total)']

## On peut ainsi construire le score départemental de chaque candidat
### construction du score de chaque candidat (en %)

#### Total général des votes par département pour calculer les pourcentages
total_par_dep = votes_departementaux.groupby('code_departement')['Nombre votes (total)'].transform('sum')


### Score en % de chaque candidat dans chaque département
votes_departementaux['Score (% votes exprimés)'] = (
    (votes_departementaux['Nombre votes (total)'] / total_par_dep) * 100
).round(2)


# Tri décroissant par département
votes_departementaux = votes_departementaux.sort_values(['code_departement', 'Nombre votes (total)'], ascending=False).reset_index(drop=True)


print(votes_departementaux[votes_departementaux['code_departement'] == '11'])
# Out:
#      code_departement               Candidat  Nombre votes (total)  \
# 1164               11          Marine LE PEN                 64027
# 1165               11        Emmanuel MACRON                 43104
# 1166               11     Jean-Luc MÉLENCHON                 42039
# 1167               11           Éric ZEMMOUR                 18434
# 1168               11          Jean LASSALLE                 12382
# 1169               11       Valérie PÉCRESSE                  7350
# 1170               11          Yannick JADOT                  6322
# 1171               11           Anne HIDALGO                  6166
# 1172               11         Fabien ROUSSEL                  5622
# 1173               11  Nicolas DUPONT-AIGNAN                  4206
# 1174               11        Philippe POUTOU                  1748
# 1175               11       Nathalie ARTHAUD                  1026
#
#       Score (% votes exprimés)
# 1164                     30.14
# 1165                     20.29
# 1166                     19.79
# 1167                      8.68
# 1168                      5.83
# 1169                      3.46
# 1170                      2.98
# 1171                       2.9
# 1172                      2.65
# 1173                      1.98
# 1174                      0.82
# 1175                      0.48

# %% [markdown]
# Affichage du tableau des votes du département 11

# %%
beau_tableau(votes_departementaux[votes_departementaux['code_departement'] == '11'],
#    col_departement='code_departement',
    col_entiers=['Nombre votes (total)'],
    col_pourcentages=['Score (% votes exprimés)'],
    titre="Résultats par Département",
    sous_titre="Détail des voix par candidat",
    date="2022",
    col_gras = "all"
)
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# GT(_tbl_data=     code_departement               Candidat  Nombre votes (total)  \
# 1164               11          Marine LE PEN                 64027
# 1165               11        Emmanuel MACRON                 43104
# 1166               11     Jean-Luc MÉLENCHON                 42039
# 1167               11           Éric ZEMMOUR                 18434
# 1168               11          Jean LASSALLE                 12382
# 1169               11       Valérie PÉCRESSE                  7350
# 1170               11          Yannick JADOT                  6322
# 1171               11           Anne HIDALGO                  6166
# 1172               11         Fabien ROUSSEL                  5622
# 1173               11  Nicolas DUPONT-AIGNAN                  4206
# 1174               11        Philippe POUTOU                  1748
# 1175               11       Nathalie ARTHAUD                  1026
#
#       Score (% votes exprimés)
# 1164                     30.14
# 1165                     20.29
# 1166                     19.79
# 1167                      8.68
# 1168                      5.83
# 1169                      3.46
# 1170                      2.98
# 1171                       2.9
# 1172                      2.65
# 1173                      1.98
# 1174                      0.82
# 1175                      0.48  , _body=<great_tables._gt_data.Body object at 0x7f32988defc0>, _boxhead=Boxhead([ColInfo(var='code_departement', type=<ColInfoTypeEnum.default: 1>, column_label='code_departement', column_align='left', column_width=None), ColInfo(var='Candidat', type=<ColInfoTypeEnum.default: 1>, column_label='Candidat', column_align='left', column_width=None), ColInfo(var='Nombre votes (total)', type=<ColInfoTypeEnum.default: 1>, column_label='Nombre votes (total)', column_align='right', column_width=None), ColInfo(var='Score (% votes exprimés)', type=<ColInfoTypeEnum.default: 1>, column_label='Score (% votes exprimés)', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f32987a3240>, _spanners=Spanners([]), _heading=Heading(title=Md(text='**Résultats par Département**'), subtitle=Md(text='Détail des voix par candidat (<i class="fa fa-calendar-o" aria-hidden="true"></i> <em>2022</em>)'), preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f3295070910>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f32950727b0>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocColumnLabels(columns='code_departement'), grpname=None, colname='code_departement', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='Candidat'), grpname=None, colname='Candidat', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='Nombre votes (total)'), grpname=None, colname='Nombre votes (total)', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='Score (% votes exprimés)'), grpname=None, colname='Score (% votes exprimés)', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=1, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=2, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=3, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=4, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=5, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=6, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=7, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=8, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname ...

# %% [markdown]
# # Question 5

# %% [markdown]
# On étudie pour chaque département la différence entre son score départemental et son score national

# %%
# lien entre les résultats nationaux et départementaux
# 1. Préparation de la table nationale (on renomme pour éviter les confusions)
df_nat_clean = votes_national[['Candidat', 'Nombre votes (total)', 'Score (% votes exprimés)']].copy()
df_nat_clean.columns = ['Candidat', 'votes_national', 'score_national']

# 2. Fusion avec la table départementale
# On utilise 'left' pour garder tous les candidats du département
score_departements = pd.merge(
    votes_departementaux, 
    df_nat_clean, 
    on='Candidat', 
    how='left'
)

# 3. Renommage des colonnes départementales pour la clarté
score_departements = score_departements.rename(columns={
    'code_departement': 'code_departement',
    'Nombre votes (total)': 'votes_departement',
    'Score (% votes exprimés)': 'score_departement'
})

print(score_departements[score_departements.code_departement=="11"])
# Out:
#      code_departement               Candidat  votes_departement  \
# 1164               11          Marine LE PEN              64027
# 1165               11        Emmanuel MACRON              43104
# 1166               11     Jean-Luc MÉLENCHON              42039
# 1167               11           Éric ZEMMOUR              18434
# 1168               11          Jean LASSALLE              12382
# 1169               11       Valérie PÉCRESSE               7350
# 1170               11          Yannick JADOT               6322
# 1171               11           Anne HIDALGO               6166
# 1172               11         Fabien ROUSSEL               5622
# 1173               11  Nicolas DUPONT-AIGNAN               4206
# 1174               11        Philippe POUTOU               1748
# 1175               11       Nathalie ARTHAUD               1026
#
#       score_departement  votes_national  score_national
# 1164              30.14         8133828           23.15
# 1165              20.29         9783058           27.85
# 1166              19.79         7712520           21.95
# 1167               8.68         2485226            7.07
# 1168               5.83         1101387            3.13
# 1169               3.46         1679001            4.78
# 1170               2.98         1627853            4.63
# 1171                2.9          616478            1.75
# 1172               2.65          802422            2.28
# 1173               1.98          725176            2.06
# 1174               0.82          268904            0.77
# 1175               0.48          197094            0.56

# %% [markdown]
# On affiche le tableau des scores par département et du score national pour chaque candidat.

# %%
# affichage tableau départemental-national

# On définit les groupes de colonnes pour la fonction
colonnes_nombres = ['votes_departement', 'votes_national']
colonnes_scores = ['score_departement', 'score_national']

# Appel de votre fonction modèle
tableau_comparatif = beau_tableau(
    score_departements.query("code_departement == '11'"), 
    col_entiers=colonnes_nombres,
    col_pourcentages=colonnes_scores,
    titre="Analyse Comparative des Résultats",
    sous_titre="Comparaison des scores départementaux vs moyenne nationale",
    date="2022",
    note="Source : Fusion des données locales et nationales",
    col_gras = "all"
)

# Affichage
tableau_comparatif
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# GT(_tbl_data=     code_departement               Candidat  votes_departement  \
# 1164               11          Marine LE PEN              64027
# 1165               11        Emmanuel MACRON              43104
# 1166               11     Jean-Luc MÉLENCHON              42039
# 1167               11           Éric ZEMMOUR              18434
# 1168               11          Jean LASSALLE              12382
# 1169               11       Valérie PÉCRESSE               7350
# 1170               11          Yannick JADOT               6322
# 1171               11           Anne HIDALGO               6166
# 1172               11         Fabien ROUSSEL               5622
# 1173               11  Nicolas DUPONT-AIGNAN               4206
# 1174               11        Philippe POUTOU               1748
# 1175               11       Nathalie ARTHAUD               1026
#
#       score_departement  votes_national  score_national
# 1164              30.14         8133828           23.15
# 1165              20.29         9783058           27.85
# 1166              19.79         7712520           21.95
# 1167               8.68         2485226            7.07
# 1168               5.83         1101387            3.13
# 1169               3.46         1679001            4.78
# 1170               2.98         1627853            4.63
# 1171                2.9          616478            1.75
# 1172               2.65          802422            2.28
# 1173               1.98          725176            2.06
# 1174               0.82          268904            0.77
# 1175               0.48          197094            0.56  , _body=<great_tables._gt_data.Body object at 0x7f32987a9c70>, _boxhead=Boxhead([ColInfo(var='code_departement', type=<ColInfoTypeEnum.default: 1>, column_label='code_departement', column_align='left', column_width=None), ColInfo(var='Candidat', type=<ColInfoTypeEnum.default: 1>, column_label='Candidat', column_align='left', column_width=None), ColInfo(var='votes_departement', type=<ColInfoTypeEnum.default: 1>, column_label='votes_departement', column_align='right', column_width=None), ColInfo(var='score_departement', type=<ColInfoTypeEnum.default: 1>, column_label='score_departement', column_align='right', column_width=None), ColInfo(var='votes_national', type=<ColInfoTypeEnum.default: 1>, column_label='votes_national', column_align='right', column_width=None), ColInfo(var='score_national', type=<ColInfoTypeEnum.default: 1>, column_label='score_national', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f32939f8af0>, _spanners=Spanners([]), _heading=Heading(title=Md(text='**Analyse Comparative des Résultats**'), subtitle=Md(text='Comparaison des scores départementaux vs moyenne nationale (<i class="fa fa-calendar-o" aria-hidden="true"></i> <em>2022</em>)'), preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f329798ce20>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f3298791cd0>, _source_notes=[Md(text='**Source : Fusion des données locales et nationales**')], _footnotes=[], _styles=[StyleInfo(locname=LocColumnLabels(columns='code_departement'), grpname=None, colname='code_departement', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='Candidat'), grpname=None, colname='Candidat', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='votes_departement'), grpname=None, colname='votes_departement', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='score_departement'), grpname=None, colname='score_departement', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='votes_national'), grpname=None, colname='votes_national', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocColumnLabels(columns='score_national'), grpname=None, colname='score_national', rownum=None, colnum=None, styles=[CellStyleText(color=None, font=None, size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=1, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=2, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=3 ...

# %% [markdown]
# # Question 6

# %% [markdown]
# Certains candidats sont surreprésentés dans certains départements

# %%
# Construction de la variable de surrepresentation

score_departements['surrepresentation'] = (score_departements['score_departement'] - score_departements['score_national']) / score_departements['score_national'] * 100

#print(score_departements.head())
beau_tableau(score_departements.head())
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# GT(_tbl_data=  code_departement            Candidat  votes_departement  score_departement  \
# 0               99     Emmanuel MACRON             224957              45.09
# 1               99  Jean-Luc MÉLENCHON             109394              21.92
# 2               99        Éric ZEMMOUR              43252               8.67
# 3               99       Yannick JADOT              40774               8.17
# 4               99       Marine LE PEN              26380               5.29
#
#    votes_national  score_national  surrepresentation
# 0         9783058           27.85          61.903052
# 1         7712520           21.95          -0.136674
# 2         2485226            7.07          22.630835
# 3         1627853            4.63          76.457883
# 4         8133828           23.15         -77.149028  , _body=<great_tables._gt_data.Body object at 0x7f32939f15c0>, _boxhead=Boxhead([ColInfo(var='code_departement', type=<ColInfoTypeEnum.default: 1>, column_label='code_departement', column_align='left', column_width=None), ColInfo(var='Candidat', type=<ColInfoTypeEnum.default: 1>, column_label='Candidat', column_align='left', column_width=None), ColInfo(var='votes_departement', type=<ColInfoTypeEnum.default: 1>, column_label='votes_departement', column_align='right', column_width=None), ColInfo(var='score_departement', type=<ColInfoTypeEnum.default: 1>, column_label='score_departement', column_align='right', column_width=None), ColInfo(var='votes_national', type=<ColInfoTypeEnum.default: 1>, column_label='votes_national', column_align='right', column_width=None), ColInfo(var='score_national', type=<ColInfoTypeEnum.default: 1>, column_label='score_national', column_align='right', column_width=None), ColInfo(var='surrepresentation', type=<ColInfoTypeEnum.default: 1>, column_label='surrepresentation', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f3298977850>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f32987925d0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f341071b750>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=1, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=2, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=3, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='code_departement', rownum=4, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=1, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=2, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=3, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='Candidat', rownum=4, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='votes_departement', rownum=0, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='votes_departement', rownum=1, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='votes_departement', rownum=2, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='votes_departement', rownum=3, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='votes_departement', rownum=4, colnum=None, styles=[CellStyleFill(color='white')]), StyleInfo(locname=LocBody(columns=None, ro ...

# %% [markdown]
# # Question 7

# %% [markdown]
# La fonction ci-après permet d'afficher les départements où un candidat est la plus surreprésenté ou sous représenté

# %%
def plot_top_surrepresentations(data, candidat, nb_dep=10):
    # 1. Filtrage pour le candidat choisi
    df_c = data[data['Candidat'] == candidat].copy()
    
    if df_c.empty:
        print(f" Le candidat '{candidat}' n'a pas été trouvé.")
        return

    # 2. Calcul de la valeur absolue pour trouver les écarts les plus grands
    df_c['abs_surrep'] = df_c['surrepresentation'].abs()

    # 3. Tri par valeur absolue et sélection du top N
    # On prend les N plus grands écarts (positifs ou négatifs)
    df_top = df_c.sort_values('abs_surrep', ascending=False).head(nb_dep)
    
    # Optionnel : On retrie par valeur réelle pour que le graphique soit ordonné de gauche à droite
    df_top = df_top.sort_values('surrepresentation', ascending=False)

    # 4. Création du graphique
    plt.figure(figsize=(10, 6))
    
    # Couleur bleue uniforme comme demandé
    sns.barplot(
        data=df_top, 
        x='surrepresentation', 
        y='code_departement', 
        color='blue',
        edgecolor='black',
        linewidth=0.5
    )

    # 5. Titre et mise en page
    plt.title(f"TOP {nb_dep} des plus grands écarts de représentation de {candidat}", fontsize=14, fontweight='bold')
    plt.xlabel("Surreprésentation (+) ou Sous-représentation (-) en %")
    plt.ylabel("Départements (Code)")
    
    # La ligne rouge à zéro devient cruciale ici pour séparer gauche/droite
    plt.axvline(x=0, color='red', linestyle='-', linewidth=1.5, alpha=0.8)
    
    # On ajoute une grille pour mieux lire les valeurs négatives
    plt.grid(axis='x', linestyle='--', alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Exemple pour Eric Zemmour**

# %%
## affichage pour Eric Zemmour
plot_top_surrepresentations(data=score_departements, candidat='Éric ZEMMOUR', nb_dep=5)

## affichage pour Emmannuel Macron
##plot_top_surrepresentations(data=score_departements, candidat='Emmanuel MACRON', nb_dep=5)

# %% [markdown]
# # 3. Un peu de cartographie

# %% [markdown]
# ## Données

# %% [markdown]
# Nous importons ici les données geojson contenant le fond de carte  des départements de France.

# %%
departement_borders = carti_download(
    values=["France"],
    crs=4326,
    borders="DEPARTEMENT",
    vectorfile_format="geojson",
    simplification=50,
    filter_by="FRANCE_ENTIERE_DROM_RAPPROCHES",
    source="EXPRESS-COG-CARTO-TERRITOIRE",
    year=2022
)

departement_borders.head()
# Out:
#   INSEE_DEP    PAYS LIBELLE_DEPARTEMENT  POPULATION  \
# 0        43  France         Haute-Loire      227570
# 1        65  France     Hautes-Pyrénées      229567
# 2        29  France           Finistère      915090
# 3        22  France       Côtes-d'Armor      600582
# 4        38  France               Isère     1271166
#
#                              SOURCE  \
# 0  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 1  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 2  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 3  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 4  IGN:EXPRESS-COG-CARTO-TERRITOIRE
#
#                                             geometry
# 0  POLYGON ((3.89745 45.35699, 3.89691 45.35631, ...
# 1  MULTIPOLYGON (((-0.09705 43.5822, -0.09642 43....
# 2  MULTIPOLYGON (((-3.97907 47.70396, -3.98004 47...
# 3  MULTIPOLYGON (((-3.20174 48.85198, -3.20193 48...
# 4  POLYGON ((5.10149 45.81356, 5.09828 45.80627, ...

# %% [markdown]
# ### Un aperçu des données pour mieux voir les noms de variables

# %%
score_departements = votes_departementaux.copy()

score_departements.head()
# Out:
#   code_departement            Candidat  Nombre votes (total)  \
# 0               99     Emmanuel MACRON                224957
# 1               99  Jean-Luc MÉLENCHON                109394
# 2               99        Éric ZEMMOUR                 43252
# 3               99       Yannick JADOT                 40774
# 4               99       Marine LE PEN                 26380
#
#    Score (% votes exprimés)
# 0                     45.09
# 1                     21.92
# 2                      8.67
# 3                      8.17
# 4                      5.29

# %% [markdown]
# ## Carte pour Marine LE PEN

# %% [markdown]
# Dans cette partie, nous avons construit une visualisation cartographique des scores électoraux par département en structurant le code en plusieurs fonctions qui se trouvent dans le fichier **utils.py**.
#
# Tout d’abord, la fonction `filtrer_candidat` permet de restreindre la base `score_departements` à un candidat donné, sans modifier les données initiales. Les données ainsi filtrées sont ensuite fusionnées avec le fond de carte des départements via la fonction `merge_carte`, afin d’associer à chaque département son score électoral.
#
# La représentation cartographique est ensuite réalisée grâce à la fonction `plot_carte`, qui génère une carte choroplèthe en paramétrant notamment les couleurs, la légende et les contours des départements pour améliorer la lisibilité. Enfin, les fonctions `carte_par_candidat` et `cartes_plusieurs_candidats` permettent respectivement d’afficher la carte pour un candidat donné ou d’automatiser la génération pour plusieurs candidats.

# %% [markdown]
# La carte des scores de Marine LE PEN met en évidence une forte structuration territoriale de son électorat. On observe des scores particulièrement élevés dans le nord et le nord-est de la France, ainsi que dans certains départements du sud, traduisant un ancrage important dans ces zones.
#
# À l’inverse, les scores apparaissent plus faibles dans l’ouest du pays, ce qui suggère une moindre implantation dans ces régions. Ces contrastes illustrent des disparités géographiques marquées, pouvant être liées à des facteurs socio-économiques ou encore la structure démographique.

# %%
## Carte pour Marine LE PEN
carte_par_candidat(score_departements, departement_borders, "Marine LE PEN",epais_lim=1.4,long_legend= 10)

# %% [markdown]
# Nous présentons ci-dessous les cartes de tous les candidats en utilisant la fonction `cartes_plusieurs_candidats` présenté ci-haut.

# %%
liste_candidats = score_departements["Candidat"].unique().tolist()

cartes_plusieurs_candidats(
    df=score_departements,
    df_geo=departement_borders,
    liste_candidats=liste_candidats,
    indicateur="Score (% votes exprimés)",
    epais_lim=1.4,
    long_legend= 10
)
